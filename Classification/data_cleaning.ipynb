# %%
import pandas as pd
import re

# %%
df = pd.read_csv('finalfinal.csv')

# %%
df
# Out:
#        Unnamed: 0.1  Unnamed: 0        artist  \
# 0                 0           0    The Weeknd
# 1                 1           1    The Weeknd
# 2                 2           2    The Weeknd
# 3                 3           3    The Weeknd
# 4                 4           4    The Weeknd
# ...             ...         ...           ...
# 20794         24556       24556  Fall Out Boy
# 20795         24557       24557  Fall Out Boy
# 20796         24558       24558  Fall Out Boy
# 20797         24559       24559  Fall Out Boy
# 20798         24560       24560  Fall Out Boy
#
#                                                    album  \
# 0                                The Highlights (Deluxe)
# 1                                The Highlights (Deluxe)
# 2                                The Highlights (Deluxe)
# 3                                The Highlights (Deluxe)
# 4                                The Highlights (Deluxe)
# ...                                                  ...
# ...

# %%
# track album track_id lyrics emotion intensity
df_final = df[['track', 'album', 'track_id', 'lyrics', 'emotion', 'intensity']]
df_final
# Out:
#                                                   track  \
# 0                               SKIN TO BONE - Acapella
# 1                            So Am I - Toby Green Remix
# 2                                                 Crazy
# 3                                                 Clown
# 4                                              Get Free
# ...                                                 ...
# 1112                                   Fight Till Death
# 1113                                              First
# 1114  If There's A God In Heaven (What's He Waiting ...
# 1115                                         VICTIMIZED
# 1116                    In The Dark - Dirty South Remix
#
#                                            album                track_id  \
# 0     LIVING THINGS: Acapellas and Instrumentals  0jw00DFjpx3AjcPtVCS1st
# 1                          So Am I (The Remixes)  26c18xZN2XSjK50hoYWQrz
# ...
