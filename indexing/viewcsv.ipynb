# %%
import pandas as pd

# %%
lyrics = pd.read_csv('final-Copy1.csv')

# %%
lyrics
# Out:
#        Unnamed: 0        artist  \
# 0               0    The Weeknd
# 1               1    The Weeknd
# 2               2    The Weeknd
# 3               3    The Weeknd
# 4               4    The Weeknd
# ...           ...           ...
# 24556       24556  Fall Out Boy
# 24557       24557  Fall Out Boy
# 24558       24558  Fall Out Boy
# 24559       24559  Fall Out Boy
# 24560       24560  Fall Out Boy
#
#                                                    album  \
# 0                                The Highlights (Deluxe)
# 1                                The Highlights (Deluxe)
# 2                                The Highlights (Deluxe)
# 3                                The Highlights (Deluxe)
# 4                                The Highlights (Deluxe)
# ...                                                  ...
# 24556                                            So Sick
# 24557  I'm Like A Lawyer With The Way I'm Always Tryi...
# ...
